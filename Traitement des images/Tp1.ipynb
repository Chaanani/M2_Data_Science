# %%
import pandas as pd
import numpy as np

# %%
data5 =pd.read_csv("Summary of 58-1.csv")
data5['label']= [5 for i in range(len(data5))]

data9 =pd.read_csv("Summary of LED-1.csv")

data9['label']= [9 for i in range(len(data9))]

# %%
data5
# Out:
#    Slice  Count  Total Area  Average Size   %Area    Mean    Mode  Perim.  \
# 0     51    145      106528       734.676   8.127  33.028  32.159  52.933
# 1     52    142      118288       833.014   9.025  33.123  32.077  62.599
# 2     53    152       85455       562.204   6.520  32.961  32.138  57.728
# 3     54    170      138687       815.806  10.581  32.965  32.447  55.798
# 4     55    222      147023       662.266  11.217  32.734  32.315  46.234
# 5     56    195      145562       746.472  11.105  32.872  32.056  56.327
# 6     57    141      137578       975.730  10.496  33.150  32.163  58.692
# 7     58    172      134024       779.209  10.225  32.921  32.174  51.646
#
#     Major  Minor  ...   Feret   FeretX   FeretY  FeretAngle  MinFeret  \
# 0  12.792  6.312  ...  13.298  557.938  767.545     138.968     6.558
# 1  13.962  6.692  ...  14.511  566.690  719.190     137.225     6.936
# 2  13.241  5.963  ...  14.107  553.651  788.730     139.083     6.265
# ...

# %%
data9
# Out:
#    Slice  Count  Total Area  Average Size  %Area    Mean    Mode   Perim.  \
# 0     91     14       38858      2775.571  2.965  94.661  97.214  141.090
# 1     92     19       39031      2054.263  2.978  87.811  92.053  105.704
# 2     93     14       36040      2574.286  2.750  94.226  95.786  161.874
# 3     94     19       38927      2048.789  2.970  88.581  91.737  107.287
# 4     95     16       38758      2422.375  2.957  90.691  95.812  121.475
# 5     96     24       39460      1644.167  3.011  83.458  84.542   85.039
# 6     97     24       39781      1657.542  3.035  84.260  86.917   87.939
# 7     98     24       39489      1645.375  3.013  81.149  84.708   84.714
#
#     Major   Minor  ...   Feret   FeretX   FeretY  FeretAngle  MinFeret  \
# 0  40.869  34.841  ...  42.401  884.643  547.214     118.839    34.295
# 1  30.219  26.067  ...  31.637  817.526  508.263     124.746    25.558
# 2  39.621  33.757  ...  42.944  954.571  492.786     125.907    33.876
# ...

# %%
Data = pd.concat([data5, data9])

# %%
Data
# Out:
#    Slice  Count  Total Area  Average Size   %Area    Mean    Mode   Perim.  \
# 0     51    145      106528       734.676   8.127  33.028  32.159   52.933
# 1     52    142      118288       833.014   9.025  33.123  32.077   62.599
# 2     53    152       85455       562.204   6.520  32.961  32.138   57.728
# 3     54    170      138687       815.806  10.581  32.965  32.447   55.798
# 4     55    222      147023       662.266  11.217  32.734  32.315   46.234
# 5     56    195      145562       746.472  11.105  32.872  32.056   56.327
# 6     57    141      137578       975.730  10.496  33.150  32.163   58.692
# 7     58    172      134024       779.209  10.225  32.921  32.174   51.646
# 0     91     14       38858      2775.571   2.965  94.661  97.214  141.090
# 1     92     19       39031      2054.263   2.978  87.811  92.053  105.704
# 2     93     14       36040      2574.286   2.750  94.226  95.786  161.874
# ...

# %%
y_train = Data["label"]
x_train = Data.drop("label", axis=1)

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt

correlation_matrix = Data.corr()
feature_correlation = correlation_matrix['label'].abs().sort_values(ascending=False)
feature_correlation = feature_correlation.drop(labels = ['label','Slice'])
plt.figure(figsize=(10, 6))
feature_correlation.plot(kind='bar', color='skyblue')
plt.title('Histogram of Feature Correlations with Target')
plt.xlabel('Features')
plt.ylabel('Absolute Correlation with Target')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from scipy.stats import pearsonr



correlations = {}
for feature in x_train.columns:
    corr, _ = pearsonr(x_train[feature], y_train)
    correlations[feature] = abs(corr)

# Converting to a Series for easy plotting
correlation_series = pd.Series(correlations)

# Plotting the histogram
plt.figure(figsize=(10, 6))
correlation_series.plot(kind='bar', color='skyblue')
plt.title('Histogram of Pearson Correlation of Features with Target')
plt.xlabel('Features')
# Out:
# Text(0.5, 0, 'Features')

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

# Obtention des importances des features
feature_importances = rf.feature_importances_

# Tri des features par leur importance
sorted_idx = np.argsort(feature_importances)[::-1]

# Sélection des features importantes
selected_features_rf = [x_train.columns[i] for i in sorted_idx]
importances_sorted = feature_importances[sorted_idx]

# Affichage des features sélectionnées et de leurs importances
selected_features_rf, importances_sorted
# Out:
# (['Perim.',
#   'Total Area',
#   'Average Size',
#   'FeretX',
#   'Count',
#   'Major',
#   'Kurt',
#   'Skew',
#   'Mode',
#   'Slice',
#   'IntDen',
#   'Median',
#   'Minor',
#   'Feret',
#   'FeretY',
#   'Mean',
#   '%Area',
#   'MinFeret',
#   'Angle',
#   'Circ.',
#   'FeretAngle',
#   'Solidity'],
#  array([0.08, 0.07, 0.07, 0.07, 0.06, 0.06, 0.05, 0.05, 0.05, 0.05, 0.05,
#         0.05, 0.04, 0.04, 0.04, 0.04, 0.04, 0.03, 0.03, 0.02, 0.01, 0.  ]))
